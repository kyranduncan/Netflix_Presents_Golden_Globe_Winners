# %%
#import 
import pandas as pd
import os
import csv

# %%
#path to CSV file
globes= os.path.join("C:/Users/kyran/Documents/Netflix_Presents_Golden_Globe_Winners/golden_globe_awards.csv")

# %%
#read CSV file
globes = pd.read_csv(globes)

#print csv file
globes.head()
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                      title   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3                      NaN  True
# 4   The Song Of Bernadette  True

# %%
#inspect data types in df
globes.dtypes
# Out:
# year_film      int64
# year_award     int64
# ceremony       int64
# category      object
# nominee       object
# title         object
# win             bool
# dtype: object

# %%
#fill the NaN values in title column with the value from the nominee column
globes.loc[globes["title"].isnull(), 'title']= globes["nominee"]
globes.head()
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                      title   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3   The Song Of Bernadette  True
# 4   The Song Of Bernadette  True

# %%
#convert title column values to uppercase
globes['title'] = globes['title'].str.upper()
globes.head()
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                      title   win
# 0  FOR WHOM THE BELL TOLLS  True
# 1  FOR WHOM THE BELL TOLLS  True
# 2   THE SONG OF BERNADETTE  True
# 3   THE SONG OF BERNADETTE  True
# 4   THE SONG OF BERNADETTE  True

# %%
#save as CSV file
globes.to_csv('globes_transformed.csv', index= True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-23-c5696d717309> in <module>
#       1 #save as CSV file
# ----> 2 globes.to_csv('globes_transformed.csv', index= True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'globes_transformed.csv'
